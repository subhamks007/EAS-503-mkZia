# %%
# %matplotlib notebook
# %matplotlib notebook




#     %matplotlib notebook will lead to interactive plots embedded within the notebook

#     %matplotlib inline will lead to static images of your plot embedded in the notebook

# %%
import matplotlib.pyplot as plt

# %%
def sim_coin_toss(number_of_simulations):
    import random
    output = {}
    for i in range(number_of_simulations):
        toss = random.randint(0,1)
        
        if toss == 0:
            toss = 'Head'
        else:
            toss = 'Tail'
            
        if toss not in output:
            output[toss] = 0
            
        output[toss] += 1
    
    return output

# %%
ten_sims = sim_coin_toss(10)

# %%
print(ten_sims)
# Out:
# {'T': 6, 'H': 4}

# %%
data = ten_sims
group_data = list(data.values())
group_names = list(data.keys())

# %%
fig, ax = plt.subplots()
ax.bar(group_names, group_data)
ax.set(xlabel='Coin', ylabel='Frequency',
       title='Simulatation with 10 Coin Tosses')
# Out:
# <img src="data:image/png;base64,..." width="640">
# [Text(0.5, 0, 'Coin'),
#  Text(0, 0.5, 'Frequency'),
#  Text(0.5, 1.0, 'Simulatation with 10 Coin Tosses')]

# %%
# https://www.simplypsychology.org/boxplots.html

import matplotlib.pyplot as plt

# Fixing random state for reproducibility

# fake up some data
spread = [1,2,3,3, 51, 52, 53,53, 120]
center = [25, 23, 24, 27, 28, 29]
data = spread + center

# %%
fig1, ax1 = plt.subplots()
ax1.set_title('Basic Plot')
ax1.boxplot(data);
# Out:
# <img src="data:image/png;base64,..." width="767.5">

# %%
import statistics
print(statistics.mean(data))
# Out:
# 26.53846153846154

# %%
print(statistics.variance(data))
# Out:
# 419.43589743589746

# %%
print(statistics.stdev(data))
# Out:
# 20.48013421430381

# %%
statistics.median(data)
# Out:
# 25

# %%
Q1, median, Q3 = statistics.quantiles(data)
print(Q1, median, Q3)
# Out:
# 3.0 27.0 52.0

# %%
sorted(data)
# Out:
# [1, 2, 3, 3, 23, 24, 25, 27, 28, 29, 51, 52, 53, 53, 120]

# %%
IQR = Q3 - Q1
Q1 - 1.5 * IQR
# Out:
# -70.5

# %%
Q3 + 1.5 * IQR
# Out:
# 125.5
